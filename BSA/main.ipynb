# %%
pwd
# Out:
# 'C:\\Users\\649518\\Documents\\BSA&HT - Comp Sci Misc\\BSA'

# %%
import os

os.chdir(r"C:\Users\649518\Documents\BSA&HT - Comp Sci Misc\BSA")

# %%
pwd
# Out:
# 'C:\\Users\\649518\\Documents\\BSA&HT - Comp Sci Misc\\BSA'

# %%
from utils import Node
# Out:
#   Cell In[16], line 1
#     from utils import Node.Node as Node
#                           ^
# SyntaxError: invalid syntax

# %%
root = Node(20)
